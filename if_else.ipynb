# %% [markdown]
# <a href="https://colab.research.google.com/github/jayx003/Python-Practice/blob/main/if_else.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem Statement: if-else**

# %%
#1. maximum between two numbers
a = int(input('Enter num1: '))
b = int(input('Enter num2: '))
if a<b:
  print('maximum num is', b)
else:
  print('maximum num is', a)
# Out:
# Enter num1: -1
# Enter num2: 0
# maximum num is 0

# %%
#2.maximum between three numbers
a = int(input('enter num1: '))
b = int(input('enter num2: '))
c = int(input('enter num3: '))

if a>b and a>c:
  largest = a
elif b>a and b>c:
  largest = b
else:
  largest = c
  print('largest num is', largest)
# Out:
# enter num1: 65
# enter num2: 32
# enter num3: 87
# largest num is 87

# %%
a = int(input('enter num1: '))
b = int(input('enter num2: '))
c = int(input('enter num3: '))
max_num = max(a,b,c)
max_num
# Out:
# enter num1: 54
# enter num2: 87
# enter num3: 35657
# 35657

# %%
#3.  check whether a number is negative, positive or zero
number = float(input('enter number: '))
if number < 0:
  print('number is negative')
elif number > 0:
  print('number is positive')
else:
  print('zero')
# Out:
# enter number: 0
# zero

# %%
#4.  check whether a number is divisible by 5 and 11 or not
number = int(input('enter nuber: '))
if number % 5 == 0 and number % 11 == 0:
  print('number is divisible by 5 and 11')
else:
  print('number is not divisible by 5 and 11')
# Out:
# enter nuber: 66
# number is not divisible by 5 and 11

# %%
# 5.check whether a number is even or odd.
number = int(input('enter number: '))
if number % 2 == 0:
  print('Number is Even')
else:
  print('Number is Odd')
# Out:
# enter number: 7
# Number is Odd

# %%
#6. check whether a year is leap year or not.
year = int(input('Enter year: '))
if year %4 == 0:
  print('Leap year')
else:
  ('not a leap year')
# Out:
# Enter year: 1900
# Leap year

# %%
#7. check whether a character is alphabet or not.
char = (input('Enter character: '))
if char.isalpha():
  print('character is alphabet')
else:
  print('not alphabet')
# Out:
# Enter character: re
# character is alphabet

# %%
#8.  input any alphabet and check whether it is vowel or consonant.
alphabet = input('enter alphabet: ')[0]
if alphabet == 'a' 'e' 'i' 'o' 'u':
  print(alphabet, 'is vowel')
else:
  print(alphabet, 'is consonant')
# Out:
# enter alphabet: rdferf
# r is consonant

# %%
#9.  check whether a character is uppercase or lowercase alphabet.
alphabet = input('Enter alphabet: ')[0]
if alphabet.isupper():
  print(alphabet, ' is in uppercase')
else:
  print(alphabet, 'is in lowercase')
# Out:
# Enter alphabet: trtyrt
# t is in lowercase

# %%
#10. count total number of notes in given amount.
amount = int(input('Enter amount: '))
avl_note = 500,200,100,50,10,5
if amount // 500 > 0:
  print(amount // 500, 'notes of 500')
elif amount // 200 > 0:
  print(amount // 200, 'notes of 200')
elif amount // 100 > 0:
  print(amount // 100, 'notes of 100')
elif amount // 50 > 0:
  print(amount // 50, 'notes of 50')
elif amount // 10 > 0:
  print(amount // 10, 'notes of 10')
elif amount // 5 > 0:
  print(amount // 5, 'notes of 5')
# Out:
# Enter amount: 780
# 1 notes of 500

# %%
#11.program to input angles of a triangle and check whether triangle is valid or not.
angle1 = int(input('Enter angle1 of triangle: '))
angle2 = int(input('Enter angle2 of triangle: '))
angle3 = int(input('Enter angle3 of triangle: '))

if angle1+angle2+angle3 == 180:
  print('valid triangle')
else:
  print('invalid triangle')
# Out:
# Enter angle1 of triangle: 45
# Enter angle2 of triangle: 45
# Enter angle3 of triangle: 45
# invalid triangle

# %%
#12. input all sides of a triangle and check whether triangle is valid or not.
side1 = int(input('Enter side1 of triangle: '))
side2 = int(input('Enter side2 of triangle: '))
side3 = int(input('Enter side3 of triangle: '))

if side1+side2>side3 and side1+side3>side2 and side2+side3>side1:
  print('valid triangle')
else:
  print('invalid triangle')
# Out:
# Enter side1 of triangle: 5
# Enter side2 of triangle: 7
# Enter side3 of triangle: 11
# valid triangle

# %%
#13. Write a Python program to check whether the triangle is equilateral, isosceles or scalene triangle.
side1 = int(input('Enter side1 of triangle: '))
side2 = int(input('Enter side2 of triangle: '))
side3 = int(input('Enter side3 of triangle: '))

if side1 == side2 == side3:
  print('equilateral triangle')
elif side1 == side2 or side2 == side3 or side1 == side3:
  print('isosceles triangle')
else:
  print('scalene triangle')

# %%
#14. Write a Python program to calculate profit or loss. Input is selling cost and actual cost.

actual_cost = float(input('Enter actual cost: '))
sell_cost = float(input('Enter selling cost: '))
profit = sell_cost - actual_cost
loss = actual_cost - sell_cost
if sell_cost>actual_cost:
  print('Your profit is', profit)
elif sell_cost < actual_cost:
  print('Your loss is',loss)
elif sell_cost == actual_cost:
  print('no Profit gained')
# Out:
# Enter actual cost: 500
# Enter selling cost: 4544432432432.43434343
# Your profit is 4544432431932.435

# %%
#15. Write a Python program to input marks of five subjects Physics, Chemistry,
#Biology, Mathematics and Computer. Calculate percentage and grade
#according to following:
#Percentage >= 90% : Grade A
#Percentage >= 80% : Grade B
#Percentage >= 70% : Grade C
#Percentage >= 60% : Grade D
#Percentage >= 40% : Grade E
#Percentage < 40% : Grade F

physics = float(input('Enter Physics marks: '))
Chemistry = float(input('Enter Chemistry marks: '))
Biology = float(input('Enter Biology marks: '))
Mathematics = float(input('Enter Mathematics marks: '))
Computer = float(input('Enter Computer marks: '))

Score = physics+ Chemistry+Biology+Mathematics+Computer
percentages = (Score/500)*100
if percentages >= 90:
  print('Grade A')
elif percentages >= 80:
  print('Grade B')
elif percentages >= 70:
  print('Grade C')
elif percentages >= 60:
  print('Grade D')
elif percentages >= 40:
  print('Grade E')
elif percentages<40:
  print('Grade F')
# Out:
# Enter Physics marks: 35
# Enter Chemistry marks: 35
# Enter Biology marks: 35
# Enter Mathematics marks: 35
# Enter Computer marks: 35
# Grade F

# %%
#16. Write a Python program to input basiPython salary of an employee and
#calculate its Gross salary according to following:
#Basic Salary <= 10000 : HRA = 20%, DA = 80%
#Basic Salary <= 20000 : HRA = 30%, DA = 90%
#Basic Salary > 20000 : HRA = 35%, DA = 95%

BasicSalary = float(input('Enter BasicSalary: '))
if BasicSalary <= 10000:
  print('Grosssalary', BasicSalary+(BasicSalary* 20/100)+(BasicSalary*80/100))
elif BasicSalary <= 20000:
  print('Gross salary', BasicSalary+(BasicSalary*30/100)+(BasicSalary*90/100))
elif BasicSalary>20000:
  print('Gross salary', BasicSalary+(BasicSalary*35/100)+(BasicSalary*95/100))
# Out:
# Enter BasicSalary: 10000
# Grosssalary 20000.0

# %%
#17. Write a Python program to input electricity unit charges and calculate total
#electricity bill according to the given condition:
#For first 50 units Rs. 0.50/unit
#For next 100 units Rs. 0.75/unit
#For next 100 units Rs. 1.25/unit
#For unit above 250 Rs. 1.50/unit
#An additional surcharge of 17% is added to the bill

unit = int(input('Enter unit consumption: '))
if unit <= 50:
  bill = unit * 0.50
elif unit <= 150:
  bill = (50*0.75) + (unit-50*0.75)
elif unit <= 250:
    bill = (50*0.75) +(100*0.75) + (unit-150*1.25)
elif unit > 250:
    bill = (50*0.75) +(100*0.75) + (100*1.25) +(unit-250*150)

total_bill = bill + (bill*0.17)
print('total bill')
# Out:
# Enter unit consumption: 67
# Your electricity bill is 61.64

# %%
print(sum)
# Out:
# 12700

# %%
#1. Write a Python program to sum all the items in a list.
list1 = [100,200,200,200,3000,4000,5000]
# total = product(list1)
# total
product = [i * i+1 for i in list1]

# %%
product
# Out:
# [10001, 40001, 40001, 40001, 9000001, 16000001, 25000001]
